# %%
import import_ipynb
import numpy as np
import matplotlib.pyplot as plt
from process_laws import simple_GBM

def data_simulation():
    return 0
# Out:
# importing Jupyter notebook from process_laws.ipynb
# Brownian motion has simulated. Shape: (100, 1), alpha = 0.2, sigma = 0.5, S0 = 100, t0 = 0, T = 1, n = 100
# Brownian motion has simulated. Shape: (100, 1), kappa = 1, theta = 100, sigma = 1, S0 = 100, t0 = 0, T = 1, n = 100

# %%
stock_parameters = {'t0': 0,
                    'T': 1,
                    'n': 100,
                    'alpha': 0.2,
                    'sigma': 0.5,
                    'S0': 100}

plt.plot( *simple_GBM(**stock_parameters) )
plt.show()
# Out:
# Brownian motion has simulated. Shape: (100, 1), alpha = 0.2, sigma = 0.5, S0 = 100, t0 = 0, T = 1, n = 100
